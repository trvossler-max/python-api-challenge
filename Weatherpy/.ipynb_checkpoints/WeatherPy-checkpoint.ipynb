# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
#Import dependencies
import pandas as pd
import json
import requests
from config import api_key
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np
from scipy.stats import linregress
from citipy import citipy
from pprint import pprint

# %% [markdown]
# ## Generate Cities List

# %%
#Generate Cities List
#Create random coordinates
lats = np.random.randint(-90, 90, size = 643)
longs = np.random.randint(-180, 180, size = 643)

coords_df = pd.DataFrame({"latitude": lats, "longitude": longs})

coords_df
# Out:
#      latitude  longitude
# 0          85         35
# 1          77        -29
# 2          71         90
# 3         -60         15
# 4         -41        -89
# ..        ...        ...
# 638        33         82
# 639       -43         85
# 640       -69         38
# 641         7         61
# 642        28          5
#
# [643 rows x 2 columns]

# %%
#Iterate through citipy to build list
cities = []

for ind, row in coords_df.iterrows():
    lat, longs = row["latitude"], row["longitude"]
    city = citipy.nearest_city(lat, longs)
    
    cities.append(city.city_name)

# %%
#set url and query
cities_s = cities
url = "http://api.openweathermap.org/data/2.5/weather?"

# Build query URL and request your results in Celsius

# Get weather data
# set up lists to hold reponse info
name = []
lat = []
lon = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []

# Loop through the list of cities and perform a request for data on each
for city in cities:
    query_url = f"{url}appid={api_key}&q="
          
    response = requests.get(query_url + city).json()
    
    
    try:
        name.append(response['name'])
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
 
        print(city)
    
    except (KeyError, IndexError):
        print("City not found... skipping.")
# Out:
# vardo
# City not found... skipping.
# talnakh
# hermanus
# ancud
# mahibadhoo
# marsh harbour
# punta arenas
# punta arenas
# bluff
# busselton
# te anau
# tsogni
# hermanus
# hobart
# avarua
# City not found... skipping.
# hermanus
# arraial do cabo
# kruisfontein
# mehamn
# rikitea
# cockburn town
# vaini
# mahebourg
# albany
# hobart
# bambous virieux
# rikitea
# margherita
# mataura
# aklavik
# dikson
# swan hill
# rikitea
# cape town
# busselton
# chokurdakh
# port alfred
# vaini
# punta arenas
# kamina
# samfya
# kapaa
# chilliwack
# atuona
# kavieng
# City not found... skipping.
# vaini
# severo-kurilsk
# atar
# ushuaia
# samarai
# lebu
# taoudenni
# new norfolk
# ribeira grande
# emerald
# avarua
# new norfolk
# aswan
# City not found... skipping.
# rikitea
# City not found... skipping.
# ushuaia
# airai
# hobyo
# rikitea
# constanza
# chuy
# City not found... skipping.
# waipawa
# biloela
# atuona
# faanui
# bela
# kupang
# khor
# ranong
# arraial do cabo
# alexandria
# qaanaaq
# rikitea
# port alfred
# City not found... skipping.
# port hedland
# oshnaviyeh
# nayudupeta
# port keats
# albany
# tanout
# City not found... skipping.
# punta arenas
# dryden
# vaini
# pilar
# port lincoln
# cockburn town
# busselton
# hilo
# City not found... skipping.
# ushuaia
# cape town
# sibolga
# krasnoselkup
# arraial do cabo
# City not found... skipping.
# yellowknife
# ushuaia
# kristiansand
# City not found... skipping.
# hilo
# karaton
# georgetown
# lebu
# ushuaia
# bluff
# City not found... skipping.
# City not found... skipping.
# te anau
# mazara del vallo
# rikitea
# chapais
# cherskiy
# ancud
# severo-kurilsk
# ilulissat
# impfondo
# vaini
# bengkulu
# albany
# ushuaia
# busselton
# City not found... skipping.
# hobart
# ushuaia
# sioux lookout
# buraydah
# kodiak
# ribeira grande
# mataura
# clyde river
# porbandar
# bredasdorp
# City not found... skipping.
# nemuro
# sivas
# uba
# busselton
# vila franca do campo
# geraldton
# albany
# puerto ayora
# City not found... skipping.
# vardo
# ushuaia
# mar del plata
# berbera
# buraydah
# vaini
# barrow
# City not found... skipping.
# punta arenas
# kodiak
# bambous virieux
# ribeira grande
# narsaq
# kapaa
# isangel
# ushuaia
# fairbanks
# khandyga
# bluff
# georgetown
# City not found... skipping.
# punta arenas
# esperance
# ushuaia
# cabedelo
# jamestown
# mar del plata
# pedernales
# savalou
# ishigaki
# City not found... skipping.
# norman wells
# new norfolk
# rikitea
# mataura
# kyle
# portland
# City not found... skipping.
# punta arenas
# meadow lake
# antofagasta
# hilo
# forestville
# samarai
# castro
# bredasdorp
# college
# margate
# punta arenas
# City not found... skipping.
# poplar bluff
# tshikapa
# cape town
# asfi
# kitui
# mahebourg
# cape town
# makaryev
# sao joao da barra
# sao filipe
# City not found... skipping.
# pevek
# yubari
# lebu
# benguela
# atuona
# sao filipe
# ushuaia
# City not found... skipping.
# hasaki
# City not found... skipping.
# albany
# rikitea
# hilo
# saint-philippe
# hithadhoo
# tasiilaq
# narsaq
# mataura
# sao filipe
# mataura
# nikel
# punta arenas
# rancho palos verdes
# puerto ayora
# zapadnaya dvina
# laguna
# bandar-e lengeh
# mataura
# adrar
# tiksi
# bonnyville
# halifax
# aranda de duero
# ushuaia
# carnarvon
# chokurdakh
# vaini
# ahipara
# athabasca
# atuona
# khatanga
# carnarvon
# mataura
# tual
# new norfolk
# sitka
# City not found... skipping.
# poum
# City not found... skipping.
# husavik
# east london
# City not found... skipping.
# albany
# busselton
# leningradskiy
# punta arenas
# alexander city
# tasiilaq
# fort wellington
# hermanus
# nikolskoye
# salalah
# ushuaia
# faanui
# rikitea
# chokurdakh
# santa maria
# narsaq
# rikitea
# svetlyy
# malakal
# canto do buriti
# rafsanjan
# samana
# butaritari
# melivoia
# brae
# whitehorse
# lorengau
# east london
# mataura
# rikitea
# atuona
# ushuaia
# salinas
# hailar
# medvedka
# maralal
# georgetown
# sobolevo
# coquimbo
# pangnirtung
# tsybuliv
# rikitea
# mashhad
# san jeronimo
# lamar
# banff
# cape town
# san cristobal
# mar del plata
# mogadishu
# faanui
# vaini
# vaini
# punta arenas
# hasaki
# hobart
# kavieng
# kamoke
# aklavik
# kodino
# san quintin
# barrow
# fort nelson
# lasa
# villa maria
# ribeira grande
# saint george
# kirakira
# busselton
# hermanus
# hobart
# punta arenas
# puerto ayora
# saint-philippe
# subiaco
# busselton
# busselton
# cidreira
# mataura
# puerto ayora
# sur
# port alfred
# tautira
# mahuva
# bambous virieux
# oktyabrskoye
# jamestown
# City not found... skipping.
# aberdeen
# hambantota
# sitka
# City not found... skipping.
# cap malheureux
# new norfolk
# City not found... skipping.
# bartica
# nouadhibou
# sistranda
# constitucion
# tasiilaq
# nhulunbuy
# talnakh
# belaya gora
# thompson
# qaanaaq
# fort wellington
# buin
# mackay
# san cristobal
# provideniya
# kailua
# butaritari
# ushuaia
# bubaque
# atuona
# inta
# butaritari
# rikitea
# vestmannaeyjar
# narsaq
# husavik
# mar del plata
# ushuaia
# sabang
# port alfred
# pangnirtung
# derzhavinsk
# quelimane
# vanimo
# upernavik
# ushuaia
# faanui
# butaritari
# rikitea
# mataura
# mahebourg
# ancud
# hermanus
# City not found... skipping.
# saldanha
# punta arenas
# axim
# san rafael
# ushuaia
# ribeira grande
# tuktoyaktuk
# east london
# jamestown
# busselton
# iqaluit
# faya
# rikitea
# ulaanbaatar
# nanortalik
# City not found... skipping.
# pisco
# rocha
# rikitea
# saint-pierre
# vao
# ushuaia
# kruisfontein
# takoradi
# westport
# saint-augustin
# amahai
# hermanus
# nikolskoye
# albany
# faya
# jamestown
# pacific grove
# punta arenas
# iqaluit
# City not found... skipping.
# saint-joseph
# bathsheba
# hobart
# rikitea
# moron
# paita
# garowe
# nikolskoye
# cabo san lucas
# zhezkazgan
# bengkulu
# mar del plata
# bambous virieux
# praia da vitoria
# souillac
# City not found... skipping.
# punta arenas
# rikitea
# kimbe
# mataura
# rikitea
# hermanus
# flinders
# atuona
# leningradskiy
# City not found... skipping.
# fayaoue
# new norfolk
# zamora
# vaini
# barrow
# heze
# thinadhoo
# buraydah
# rikitea
# narsaq
# tuktoyaktuk
# miandrivazo
# torbay
# vaini
# husavik
# ushuaia
# salalah
# goure
# busselton
# flinders
# jamestown
# hermanus
# City not found... skipping.
# cherskiy
# talnakh
# ushuaia
# ushuaia
# kapaa
# mahebourg
# City not found... skipping.
# arraial do cabo
# chuy
# te anau
# kungurtug
# provideniya
# City not found... skipping.
# geraldton
# quincy
# esperance
# ponta do sol
# mananara
# City not found... skipping.
# sistranda
# camacha
# punta arenas
# katsuura
# chokurdakh
# vardo
# bredasdorp
# chokurdakh
# te anau
# dingle
# City not found... skipping.
# belyy
# xiaoweizhai
# hobart
# rikitea
# punta arenas
# kankakee
# hobart
# mogadishu
# rikitea
# mar del plata
# rikitea
# City not found... skipping.
# klaksvik
# yellowknife
# ahuimanu
# touros
# bethel
# hithadhoo
# rikitea
# barrow
# ponta delgada
# albany
# vao
# arraial do cabo
# wuwei
# mataura
# albany
# hobart
# ribeira grande
# mataura
# thompson
# hobart
# City not found... skipping.
# sattahip
# City not found... skipping.
# constitucion
# mataura
# bethel
# rikitea
# coquimbo
# primorsko-akhtarsk
# fortuna
# kapaa
# hermanus
# faanui
# dubai
# bambous virieux
# punta arenas
# guerrero negro
# yarmouth
# esil
# basco
# oranjemund
# saldanha
# kapaa
# punta arenas
# mataura
# nikolskoye
# ushuaia
# yellowknife
# qaqortoq
# City not found... skipping.
# torbay
# daoukro
# turukhansk
# City not found... skipping.
# henties bay
# port elizabeth
# noumea
# City not found... skipping.
# rikitea
# hirara
# City not found... skipping.
# punta arenas
# kahului
# City not found... skipping.
# dongobesh
# arraial do cabo
# punta arenas
# broome
# puerto ayora
# egvekinot
# bontang
# luderitz
# pilar
# City not found... skipping.
# arraial do cabo
# City not found... skipping.
# saint george
# pisco
# kapaa
# norman wells
# hobart
# upington
# tuktoyaktuk
# saint-augustin
# mar del plata
# sitka
# atuona
# albany
# khatanga
# avare
# sur
# tuktoyaktuk
# City not found... skipping.
# ordubad
# omboue
# ust-ordynskiy
# kozhva
# chunoyar
# leeton
# eureka
# atuona
# saint-pierre
# petropavlovka
# City not found... skipping.
# san ignacio
# joshimath
# busselton
# port alfred
# bandarbeyla
# City not found... skipping.

# %%
#Create dataframe
weather_dict = {"City Name": name, "Lat": lat, "Lng": lon, "Max Temp": max_temp, "Humidity": humidity, "Cloudiness": cloudiness, "Wind Speed":
    wind_speed, "Country": country, "Date": date}

weather_data = pd.DataFrame(weather_dict)

weather_data
# Out:
#        City Name      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Vardø  70.3705   31.1107    284.26        87           7
# 1        Talnakh  69.4865   88.3972    281.97        54          79
# 2       Hermanus -34.4187   19.2345    285.87        66          76
# 3          Ancud -41.8697  -73.8203    279.99        91          76
# 4     Mahibadhoo   3.7833   72.9667    301.34        72          86
# ..           ...      ...       ...       ...       ...         ...
# 585  San Ignacio  17.1561  -89.0714    296.23        94           0
# 586    Joshīmath  30.5667   79.5667    294.59        94          99
# 587    Busselton -33.6500  115.3333    287.06        76          39
# 588  Port Alfred -33.5906   26.8910    293.72        29          16
# 589  Bandarbeyla   9.4942   50.8122    302.20        52          64
#
#      Wind Speed Country        Date
# 0          6.97      NO  1626064086
# 1          4.39      RU  1626064087
# 2          5.48      ZA  1626064087
# 3          1.44      CL  1626064088
# 4          6.25      MV  1626063800
# ..          ...     ...         ...
# 585        0.00      BZ  1626064232
# 586        0.37      IN  1626064233
# 587       11.25      AU  1626064167
# 588        5.18      ZA  1626064233
# 589       13.75      SO  1626064233
#
# [590 rows x 9 columns]

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
